# %% [markdown]
# # Heatmaps -Triaxiality vs effective strain

# %% [markdown]
# ### Import packages:

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Data loading:

# %%
uni1_path_A = r"C:\Users\Laura\Dropbox (The University of Manchester)\Matflow_Laura\Uniaxial_tensile_test_2021-07-16-094225"
uni2_path_A = r"C:\Users\Laura\Dropbox (The University of Manchester)\Matflow_Laura\Uniaxial_tensile_test_2021-07-17-162259"
uni1_path_B = r"C:\Users\Laura\Dropbox (The University of Manchester)\Matflow_Laura\Uniaxial_tensile_test_2021-07-16-095005"
uni2_path_B = r"C:\Users\Laura\Dropbox (The University of Manchester)\Matflow_Laura\Uniaxial_tensile_test_2021-07-17-162559"
uni1_path_C = r"C:\Users\Laura\Dropbox (The University of Manchester)\Matflow_Laura\Uniaxial_tensile_test_2021-07-16-095455"
uni2_path_C = r"C:\Users\Laura\Dropbox (The University of Manchester)\Matflow_Laura\Uniaxial_tensile_test_2021-07-17-162929"
ps1_path_A = r"C:\Users\Laura\Dropbox (The University of Manchester)\Matflow_Laura\Plane_strain_tension_2021-07-15-184146"
ps2_path_A = r"C:\Users\Laura\Dropbox (The University of Manchester)\Matflow_Laura\Plane_strain_tension_2021-07-17-163300"
ps1_path_B = r"C:\Users\Laura\Dropbox (The University of Manchester)\Matflow_Laura\Plane_strain_tension_2021-07-16-093057"
ps2_path_B = r"C:\Users\Laura\Dropbox (The University of Manchester)\Matflow_Laura\Plane_strain_tension_2021-07-17-163514"
ps1_path_C = r"C:\Users\Laura\Dropbox (The University of Manchester)\Matflow_Laura\Plane_strain_tension_2021-07-16-093451"
ps2_path_C = r"C:\Users\Laura\Dropbox (The University of Manchester)\Matflow_Laura\Plane_strain_tension_2021-07-17-163744"

# %%
data_uni1A = pd.read_csv(uni1_path_A+'/uniA.csv')
data_uni2A = pd.read_csv(uni2_path_A+'/uniA.csv')
data_uni1B = pd.read_csv(uni1_path_B+'/uniB.csv')
data_uni2B = pd.read_csv(uni2_path_B+'/uniB.csv')
data_uni1C = pd.read_csv(uni1_path_C+'/uniC.csv')
data_uni2C = pd.read_csv(uni2_path_C+'/uniC.csv')
data_pl1A = pd.read_csv(ps1_path_A+'/planeA.csv')
data_pl2A = pd.read_csv(ps2_path_A+'/planeA.csv')
data_pl1B = pd.read_csv(ps1_path_B+'/planeB.csv')
data_pl2B = pd.read_csv(ps2_path_B+'/planeB.csv')
data_pl1C = pd.read_csv(ps1_path_C+'/planeC.csv')
data_pl2C = pd.read_csv(ps2_path_C+'/planeC.csv')

# %% [markdown]
# ### Calulate hydrostratic stress:

# %% [markdown]
# Alloy A

# %%
sh_uni1A=(data_uni1A['1_constituent/generic/sigma:0']+data_uni1A['1_constituent/generic/sigma:4']+data_uni1A['1_constituent/generic/sigma:8'])/3
sh_uni2A=(data_uni2A['1_constituent/generic/sigma:0']+data_uni2A['1_constituent/generic/sigma:4']+data_uni2A['1_constituent/generic/sigma:8'])/3
sh_pl1A=(data_pl1A['1_constituent/generic/sigma:0']+data_pl1A['1_constituent/generic/sigma:4']+data_pl1A['1_constituent/generic/sigma:8'])/3
sh_pl2A=(data_pl2A['1_constituent/generic/sigma:0']+data_pl2A['1_constituent/generic/sigma:4']+data_pl2A['1_constituent/generic/sigma:8'])/3

# %% [markdown]
# Alloy B

# %%
sh_uni1B=(data_uni1B['1_constituent/generic/sigma:0']+data_uni1B['1_constituent/generic/sigma:4']+data_uni1B['1_constituent/generic/sigma:8'])/3
sh_uni2B=(data_uni2B['1_constituent/generic/sigma:0']+data_uni2B['1_constituent/generic/sigma:4']+data_uni2B['1_constituent/generic/sigma:8'])/3
sh_pl1B=(data_pl1B['1_constituent/generic/sigma:0']+data_pl1B['1_constituent/generic/sigma:4']+data_pl1B['1_constituent/generic/sigma:8'])/3
sh_pl2B=(data_pl2B['1_constituent/generic/sigma:0']+data_pl2B['1_constituent/generic/sigma:4']+data_pl2B['1_constituent/generic/sigma:8'])/3

# %% [markdown]
# Alloy C

# %%
sh_uni1C=(data_uni1C['1_constituent/generic/sigma:0']+data_uni1C['1_constituent/generic/sigma:4']+data_uni1C['1_constituent/generic/sigma:8'])/3
sh_uni2C=(data_uni2C['1_constituent/generic/sigma:0']+data_uni2C['1_constituent/generic/sigma:4']+data_uni2C['1_constituent/generic/sigma:8'])/3
sh_pl1C=(data_pl1C['1_constituent/generic/sigma:0']+data_pl1C['1_constituent/generic/sigma:4']+data_pl1C['1_constituent/generic/sigma:8'])/3
sh_pl2C=(data_pl2C['1_constituent/generic/sigma:0']+data_pl2C['1_constituent/generic/sigma:4']+data_pl2C['1_constituent/generic/sigma:8'])/3

# %% [markdown]
# ### Heat maps with histograms:

# %%
data_uni1A['$\u03B5_{e}$ (%)']=data_uni1A['1_constituent/generic/epsilon_V^0(F)_vM']*100
data_uni1A['Triaxiality']=sh_uni1A/data_uni1A["1_constituent/generic/sigma_vM"]

print('Uniaxial_sim1_AlloyA')
print('Max.', round(max(data_uni1A['Triaxiality']),2))

sns.jointplot(data=data_uni1A, x="$\u03B5_{e}$ (%)", y="Triaxiality", xlim=[0,30],ylim=[-0.25,1.25], kind="hex", color='orange')
plt.rcParams['axes.labelsize'] = 30
# Out:
# Uniaxial_sim1_AlloyA
# Max. 1.89

# %%
data_uni2A['$\u03B5_{e}$ (%)']=data_uni2A['1_constituent/generic/epsilon_V^0(F)_vM']*100
data_uni2A['Triaxiality']=sh_uni2A/data_uni2A["1_constituent/generic/sigma_vM"]

print('Uniaxial_sim2_AlloyA')
print('Max.', round(max(data_uni2A['Triaxiality']),2))

sns.jointplot(data=data_uni2A, x="$\u03B5_{e}$ (%)", y="Triaxiality", xlim=[0,30],ylim=[-0.25,1.25],kind="hex", color='orange')
plt.rcParams['axes.labelsize'] = 30
# Out:
# Uniaxial_sim2_AlloyA
# Max. 1.84

# %%
data_pl1A['$\u03B5_{e}$ (%)']=data_pl1A['1_constituent/generic/epsilon_V^0(F)_vM']*100
data_pl1A['Triaxiality']=sh_pl1A/data_pl1A["1_constituent/generic/sigma_vM"]

print('Plane_strain_sim1_AlloyA')
print('Max.', round(max(data_pl1A['Triaxiality']),2))

sns.jointplot(data=data_pl1A, x="$\u03B5_{e}$ (%)", y="Triaxiality", xlim=[0,30],ylim=[-0.25,1.25],kind="hex", color='orange')
plt.rcParams['axes.labelsize'] = 30
# Out:
# Plane_strain_sim1_AlloyA
# Max. 2.42

# %%
data_pl2A['$\u03B5_{e}$ (%)']=data_pl2A['1_constituent/generic/epsilon_V^0(F)_vM']*100
data_pl2A['Triaxiality']=sh_pl2A/data_pl2A["1_constituent/generic/sigma_vM"]

print('Plane_strain_sim2_AlloyA')
print('Max.', round(max(data_pl2A['Triaxiality']),2))

sns.jointplot(data=data_pl2A, x="$\u03B5_{e}$ (%)", y="Triaxiality", xlim=[0,30],ylim=[-0.25,1.25],kind="hex", color='orange')
plt.rcParams['axes.labelsize'] = 30
# Out:
# Plane_strain_sim2_AlloyA
# Max. 2.13

# %%
data_uni1B['$\u03B5_{e}$ (%)']=data_uni1B['1_constituent/generic/epsilon_V^0(F)_vM']*100
data_uni1B['Triaxiality']=sh_uni1B/data_uni1B["1_constituent/generic/sigma_vM"]

print('Uniaxial_sim1_AlloyB')
print('Max.', round(max(data_uni1B['Triaxiality']),2))

sns.jointplot(data=data_uni1B, x="$\u03B5_{e}$ (%)", y="Triaxiality",xlim=[0,30],ylim=[-0.25,1.25],kind="hex", color='orange')
plt.rcParams['axes.labelsize'] = 30
# Out:
# Uniaxial_sim1_AlloyB
# Max. 1.92

# %%
data_uni2B['$\u03B5_{e}$ (%)']=data_uni2B['1_constituent/generic/epsilon_V^0(F)_vM']*100
data_uni2B['Triaxiality']=sh_uni2B/data_uni2B["1_constituent/generic/sigma_vM"]

print('Uniaxial_sim2_AlloyB')
print('Max.', round(max(data_uni2B['Triaxiality']),2))

sns.jointplot(data=data_uni2B, x="$\u03B5_{e}$ (%)", y="Triaxiality",xlim=[0,30],ylim=[-0.25,1.25],kind="hex", color='orange')
plt.rcParams['axes.labelsize'] = 30
# Out:
# Uniaxial_sim2_AlloyB
# Max. 1.97

# %%
data_pl1B['$\u03B5_{e}$ (%)']=data_pl1B['1_constituent/generic/epsilon_V^0(F)_vM']*100
data_pl1B['Triaxiality']=sh_pl1B/data_pl1B["1_constituent/generic/sigma_vM"]

print('Plane_strain_sim1_AlloyB')
print('Max.', round(max(data_pl1B['Triaxiality']),2))

sns.jointplot(data=data_pl1B, x="$\u03B5_{e}$ (%)", y="Triaxiality",xlim=[0,30],ylim=[-0.25,1.25],kind="hex", color='orange')
plt.rcParams['axes.labelsize'] = 30
# Out:
# Plane_strain_sim1_AlloyB
# Max. 2.75

# %%
data_pl2B['$\u03B5_{e}$ (%)']=data_pl2B['1_constituent/generic/epsilon_V^0(F)_vM']*100
data_pl2B['Triaxiality']=sh_pl2B/data_pl2B["1_constituent/generic/sigma_vM"]

print('Plane_strain_sim2_AlloyB')
print('Max.', round(max(data_pl2B['Triaxiality']),2))

sns.jointplot(data=data_pl2B, x="$\u03B5_{e}$ (%)", y="Triaxiality",xlim=[0,30],ylim=[-0.25,1.25],kind="hex", color='orange')
plt.rcParams['axes.labelsize'] = 30
# Out:
# Plane_strain_sim2_AlloyB
# Max. 2.35

# %%
data_uni1C['$\u03B5_{e}$ (%)']=data_uni1C['1_constituent/generic/epsilon_V^0(F)_vM']*100
data_uni1C['Triaxiality']=sh_uni1C/data_uni1C["1_constituent/generic/sigma_vM"]

print('Uniaxial_sim1_AlloyC')
print('Max.', round(max(data_uni1C['Triaxiality']),2))

sns.jointplot(data=data_uni1C, x="$\u03B5_{e}$ (%)", y="Triaxiality",xlim=[0,30],ylim=[-0.25,1.25],kind="hex", color='orange')
plt.rcParams['axes.labelsize'] = 30
# Out:
# Uniaxial_sim1_AlloyC
# Max. 1.97

# %%
data_uni2C['$\u03B5_{e}$ (%)']=data_uni2C['1_constituent/generic/epsilon_V^0(F)_vM']*100
data_uni2C['Triaxiality']=sh_uni2C/data_uni2C["1_constituent/generic/sigma_vM"]

print('Uniaxial_sim2_AlloyC')
print('Max.', round(max(data_uni2C['Triaxiality']),2))

sns.jointplot(data=data_uni2C, x="$\u03B5_{e}$ (%)", y="Triaxiality",xlim=[0,30],ylim=[-0.25,1.25],kind="hex", color='orange')
plt.rcParams['axes.labelsize'] = 30
# Out:
# Uniaxial_sim2_AlloyC
# Max. 1.95

# %%
data_pl1C['$\u03B5_{e}$ (%)']=data_pl1C['1_constituent/generic/epsilon_V^0(F)_vM']*100
data_pl1C['Triaxiality']=sh_pl1C/data_pl1C["1_constituent/generic/sigma_vM"]

print('Plane_strain_sim1_AlloyC')
print('Max.', round(max(data_pl1C['Triaxiality']),2))

sns.jointplot(data=data_pl1C, x="$\u03B5_{e}$ (%)", y="Triaxiality",xlim=[0,30],ylim=[-0.25,1.25],kind="hex", color='orange')
plt.rcParams['axes.labelsize'] = 30
# Out:
# Plane_strain_sim1_AlloyC
# Max. 2.3

# %%
data_pl2C['$\u03B5_{e}$ (%)']=data_pl2C['1_constituent/generic/epsilon_V^0(F)_vM']*100
data_pl2C['Triaxiality']=sh_pl2C/data_pl2C["1_constituent/generic/sigma_vM"]

print('Plane_strain_sim2_AlloyC')
print('Max.', round(max(data_pl2C['Triaxiality']),2))

sns.jointplot(data=data_pl2C, x="$\u03B5_{e}$ (%)", y="Triaxiality",xlim=[0,30],ylim=[-0.25,1.25],kind="hex", color='orange')
plt.rcParams['axes.labelsize'] = 30
# Out:
# Plane_strain_sim2_AlloyC
# Max. 2.53
